# %%
# %load_ext autoreload
# %autoreload 2

import utils

# %%
test = utils.HiResRun(['g.e22.G1850ECO_JRA_HR.TL319_t13.001', 'g.e22.G1850ECO_JRA_HR.TL319_g17.001'])

# %%
utils.plot_dict_with_date_keys(test.get_co2calc_warning_cnt(), title='co2calc warnings')
