# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import utils

# %%
cases = dict()
cases['001'] = utils.HiResRun(['g.e22.G1850ECO_JRA_HR.TL319_t13.001', 'g.e22.G1850ECO_JRA_HR.TL319_g17.001'])
cases['002'] = utils.HiResRun('g.e22.G1850ECO_JRA_HR.TL319_t13.002')
cases['003'] = utils.HiResRun('g.e22.G1850ECO_JRA_HR.TL319_t13.003')
cases['004'] = utils.HiResRun('g.e22.G1850ECO_JRA_HR.TL319_t13.004')

# %%
# get_co2calc_warning_cnt now counts each it value separately
# So [292, 204, 82, 1] => 292 warnings at it=1, 204 at it=2, 82 at it=3, and 1 at it=4
cases['002'].get_co2calc_warning_cnt()
# Out:
# {'0001-01-01': [16, 4, 2, 0],
#  '0001-01-02': [0, 0, 0, 0],
#  '0001-01-03': [0, 0, 0, 0],
#  '0001-01-04': [0, 0, 0, 0],
#  '0001-01-05': [0, 0, 0, 0],
#  '0001-01-06': [0, 0, 0, 0],
#  '0001-01-07': [0, 0, 0, 0],
#  '0001-01-08': [0, 0, 0, 0],
#  '0001-01-09': [0, 0, 0, 0],
#  '0001-01-10': [0, 0, 0, 0],
#  '0001-01-11': [0, 0, 0, 0],
#  '0001-01-12': [0, 0, 0, 0],
#  '0001-01-13': [0, 0, 0, 0],
#  '0001-01-14': [0, 0, 0, 0],
#  '0001-01-15': [0, 0, 0, 0],
#  '0001-01-16': [0, 0, 0, 0],
#  '0001-01-17': [0, 0, 0, 0],
#  '0001-01-18': [0, 0, 0, 0],
#  '0001-01-19': [0, 0, 0, 0],
#  '0001-01-20': [0, 0, 0, 0],
#  '0001-01-21': [0, 0, 0, 0],
#  '0001-01-22': [0, 0, 0, 0],
#  '0001-01-23': [0, 0, 0, 0],
#  '0001-01-24': [0, 0, 0, 0],
#  '0001-01-25': [0, 0, 0, 0],
#  '0001-01-26': [0, 0, 0, 0],
#  '0001-01-27': [0, 0, 0, 0],
#  '0001-01-28': [0, 0, 0, 0],
#  '0001-01-29': [0, 0, 0, 0],
#  '0001-01-30': [0, 0, 0, 0],
#  '0001-01-31': [0, 0, 0, 0],
#  '0001-02-01': [0, 0, 0, 0],
#  '0001-02-02': [0, 0, 0, 0],
#  '0001-02-03': [0, 0, 0, 0],
#  '0001-02-04': [0, 0, 0, 0],
#  '0001-02-05': [0, 0, 0, 0],
#  '0001-02-06': [0, 0, 0, 0],
#  '0001-02-07': [0, 0, 0, 0],
#  '0001-02-08': [4, 0, 0, 0],
#  '0001-02-09': [8, 0, 0, 0],
#  '0001-02-10': [2, 0, 0, 0],
#  '0001-02-11': [0, 0, 0, 0],
#  '0001-02-12': [0, 0, 0, 0],
#  '0001-02-13': [0, 0, 0, 0],
#  '0001-02-14': [0, 0, 0, 0],
#  '0001-02-15': [0, 0, 0, 0],
#  '0001-02-16': [0, 0, 0, 0],
#  '0001-02-17': [0, 0, 0, 0],
#  '0001-02-18': [0, 0, 0, 0],
#  '0001-02-19': [0, 0, 0, 0],
#  '0001-02-20': [0, 0, 0, 0],
#  '0001-02-21': [0, 0, 0, 0],
#  '0001-02-22': [0, 0, 0, 0],
#  '0001-02-23': [0, 0, 0, 0],
#  '0001-02-24': [0, 0, 0, 0],
#  '0001-02-25': [0, 0, 0, 0],
#  '0001-02-26': [0, 0, 0, 0],
#  '0001-02-27': [0, 0, 0, 0],
#  '0001-02-28': [0, 0, 0, 0],
#  '0001-03-01': [0, 0, 0, 0],
#  '0001-03-02': [0, 0, 0, 0],
#  '0001-03-03': [0, 0, 0, 0],
#  '0001-03-04': [0, 0, 0, 0],
#  '0001-03-05': [0, 0, 0, 0],
#  '0001-03-06': [0, 0, 0, 0],
#  '0001-03-07': [0, 0, 0, 0],
#  '0001-03-08': [0, 0, 0, 0],
#  '0001-03-09': [0, 0, 0, 0],
#  '0001-03-10': [0, 0, 0, 0],
#  '0001-03-11': [0, 0, 0, 0],
#  '0001-03-12': [0, 0, 0, 0],
#  '0001-03-13': [0, 0, 0, 0],
#  '0001-03-14': [0, 0, 0, 0],
#  '0001-03-15': [0, 0, 0, 0],
#  '0001-03-16': [0, 0, 0, 0],
#  '0001-03-17': [0, 0, 0, 0],
#  '0001-03-18': [0, 0, 0, 0],
#  '0001-03-19': [0, 0, 0, 0],
#  '0001-03-20': [0, 0, 0, 0],
#  '0001-03-21': [0, 0, 0, 0],
#  '0001-03-22': [0, 0, 0, 0],
#  '0001-03-23': [0, 0, 0, 0],
#  '0001-03-24': [0, 0, 0, 0],
#  '0001-03-25': [0, 0, 0, 0],
#  '0001-03-26': [0, 0, 0, 0],
#  '0001-03-27': [0, 0, 0, 0],
#  '0001-03-28': [0, 0, 0, 0],
#  '0001-03-29': [0, 0, 0, 0],
#  '0001-03-30': [0, 0, 0, 0],
#  '0001-03-31': [0, 0, 0, 0],
#  '0001-04-01': [0, 0, 0, 0],
#  '0001-04-02': [108, 8, 0, 0],
#  '0001-04-03': [0, 0, 0, 0],
#  '0001-04-04': [0, 0, 0, 0],
#  '0001-04-05': [0, 0, 0, 0],
#  '0001-04-06': [0, 0, 0, 0],
#  '0001-04-07': [0, 0, 0, 0],
#  '0001-04-08': [0, 0, 0, 0],
#  '0001-04-09': [0, 0, 0, 0],
#  '0001-04-10': [0, 0, 0, 0],
#  '0001-04-11': [0, 0, 0, 0],
#  '0001-04-12': [0, 0, 0, 0],
#  '0001-04-13': [0, 0, 0, 0],
#  '0001-04-14': [0, 0, 0, 0],
#  '0001-04-15': [0, 0, 0, 0],
#  '0001-04-16': [0, 0, 0, 0],
#  '0001-04-17': [0, 0, 0, 0],
#  '0001-04-18': [0, 0, 0, 0],
#  '0001-04-19': [0, 0, 0, 0],
#  '0001-04-20': [0, 0, 0, 0],
#  '0001-04-21': [0, 0, 0, 0],
#  '0001-04-22': [0, 0, 0, 0],
#  '0001-04-23': [0, 0, 0, 0],
#  '0001-04-24': [0, 0, 0, 0],
#  '0001-04-25': [0, 0, 0, 0],
#  '0001-04-26': [0, 0, 0, 0],
#  '0001-04-27': [0, 0, 0, 0],
#  '0001-04-28': [0, 0, 0, 0],
#  '0001-04-29': [0, 0, 0, 0],
#  '0001-04-30': [0, 0, 0, 0],
#  '0001-05-01': [0, 0, 0, 0],
#  '0001-05-02': [0, 0, 0, 0],
#  '0001-05-03': [0, 0, 0, 0],
#  '0001-05-04': [0, 0, 0, 0],
#  '0001-05-05': [366, 237, 103, 1],
#  'cesm.log.3186182.chadmin1.ib0.cheyenne.ucar.edu.200726-142958': [0, 0, 0, 0]}

# %%
utils.plot_dict_with_date_keys(cases['001'].get_co2calc_warning_cnt(),
                               title='co2calc warnings',
                               legend=[f'it = {it}' for it in range(1,5)])

# %%
utils.plot_dict_with_date_keys(cases['002'].get_co2calc_warning_cnt(),
                               title='co2calc warnings',
                               legend=[f'it = {it}' for it in range(1,5)])

# %%
utils.plot_dict_with_date_keys(cases['003'].get_co2calc_warning_cnt(),
                               title='co2calc warnings',
                               legend=[f'it = {it}' for it in range(1,5)])

# %%
utils.plot_dict_with_date_keys(cases['004'].get_co2calc_warning_cnt(),
                               title='co2calc warnings',
                               legend=[f'it = {it}' for it in range(1,5)])
