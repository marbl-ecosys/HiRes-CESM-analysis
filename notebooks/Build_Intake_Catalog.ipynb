# %% [markdown]
# # Use ecgtools to create an intake-esm catalog for the timeseries files
#
# Prior to running this notebook, I requested a single node with 36 cores which enables the `njobs=36` specification (using 36 cores to parallelize the catalog building process)
#
# In this case, we need the `Builder` object, and the `parse_cesm_timeseries` parser

# %%
from ecgtools import Builder
from ecgtools.parsers.cesm import parse_cesm_timeseries

# %% [markdown]
# ## Setup the catalog

# %% [markdown]
# Setup the builder - this case, we looked at the directory structure ahead of time and identified the `depth=4`

# %%
b = Builder(
    "/glade/campaign/cesm/development/bgcwg/projects/hi-res_JRA/cases/",
    depth=4,
    parsing_func=parse_cesm_timeseries,
    exclude_patterns=["*/hist/*", "*/rest/*"],
    njobs=36,
)

# %% [markdown]
# ## Build the catalog

# %%
b.build()
# Out:
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# [Parallel(n_jobs=36)]: Done   3 out of   8 | elapsed:    0.4s remaining:    0.6s
# [Parallel(n_jobs=36)]: Done   5 out of   8 | elapsed:    0.5s remaining:    0.3s
# [Parallel(n_jobs=36)]: Done   8 out of   8 | elapsed:    1.9s finished
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# [Parallel(n_jobs=36)]: Done  90 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=36)]: Done 216 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=36)]: Done 378 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=36)]: Done 576 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=36)]: Done 810 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=36)]: Done 1080 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=36)]: Done 1386 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=36)]: Done 1728 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=36)]: Done 2106 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=36)]: Done 2520 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=36)]: Done 2970 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=36)]: Done 3852 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=36)]: Done 4896 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=36)]: Done 6012 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=36)]: Done 7200 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=36)]: Done 8460 tasks      | elapsed:   38.0s
# [Parallel(n_jobs=36)]: Done 9792 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=36)]: Done 11196 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=36)]: Done 12672 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=36)]: Done 14220 tasks      | elapsed:   58.5s
# [Parallel(n_jobs=36)]: Done 15840 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=36)]: Done 17532 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=36)]: Done 17986 out of 17986 | elapsed:  1.1min finished
# Builder(root_path=PosixPath('/glade/campaign/cesm/development/bgcwg/projects/hi-res_JRA/cases'), extension='.nc', depth=4, exclude_patterns=['*/hist/*', '*/rest/*'], parsing_func=<function parse_cesm_timeseries at 0x2b8ab803db00>, njobs=36)

# %% [markdown]
# ## Take a quick look at the catalog

# %%
b.df
# Out:
#       component   stream                                 case  member_id  \
# 0           ocn    pop.h  g.e22.G1850ECO_JRA_HR.TL319_t13.003        3.0
# 1           ocn    pop.h  g.e22.G1850ECO_JRA_HR.TL319_t13.003        3.0
# 2           ocn    pop.h  g.e22.G1850ECO_JRA_HR.TL319_t13.003        3.0
# 3           ocn    pop.h  g.e22.G1850ECO_JRA_HR.TL319_t13.003        3.0
# 4           ocn    pop.h  g.e22.G1850ECO_JRA_HR.TL319_t13.003        3.0
# ...         ...      ...                                  ...        ...
# 17981       ice  cice.h1  g.e22.G1850ECO_JRA_HR.TL319_t13.004        4.0
# 17982       ice  cice.h1  g.e22.G1850ECO_JRA_HR.TL319_t13.004        4.0
# 17983       ice  cice.h1  g.e22.G1850ECO_JRA_HR.TL319_t13.004        4.0
# 17984       ice  cice.h1  g.e22.G1850ECO_JRA_HR.TL319_t13.004        4.0
# 17985       ice  cice.h1  g.e22.G1850ECO_JRA_HR.TL319_t13.004        4.0
#
#                            variable  start_time    end_time  \
# 0      cocco_C_lim_Cweight_avg_100m     0003-01     0003-12
# 1         sp_N_lim_Cweight_avg_100m     0002-01     0002-12
# 2                   DOP_diaz_uptake     0002-01     0002-12
# 3                          POC_PROD     0004-01     0004-12
# 4                     POC_FLUX_100m     0003-01     0003-12
# ...                             ...         ...         ...
# 17981                      dvidtd_d  0029-01-01  0029-12-31
# 17982                          hi_d  0007-01-01  0007-12-31
# 17983                          hi_d  0034-01-01  0034-12-31
# 17984                      dvidtt_d  0034-01-01  0034-12-31
# 17985                      dvidtt_d  0031-01-01  0031-12-31
#
#               time_range                                          long_name  \
# 0          000301-000312  Coccolithophores C Limitation, carbon biomass ...
# 1          000201-000212  Small Phyto N Limitation, carbon biomass weigh...
# 2          000201-000212                              Diazotroph DOP Uptake
# 3          000401-000412                                     POC Production
# 4          000301-000312                                   POC Flux at 100m
# ...                  ...                                                ...
# 17981  00290101-00291231                           volume tendency dynamics
# 17982  00070101-00071231                       grid cell mean ice thickness
# 17983  00340101-00341231                       grid cell mean ice thickness
# 17984  00340101-00341231                             volume tendency thermo
# 17985  00310101-00311231                             volume tendency thermo
#
#                units  vertical_levels frequency  \
# 0                  1              1.0   month_1
# 1                  1              1.0   month_1
# 2         mmol/m^3/s              1.0   month_1
# 3         mmol/m^3/s              1.0   month_1
# 4      mmol/m^3 cm/s              1.0   month_1
# ...              ...              ...       ...
# 17981         cm/day              1.0     day_1
# 17982              m              1.0     day_1
# 17983              m              1.0     day_1
# 17984         cm/day              1.0     day_1
# 17985         cm/day              1.0     day_1
#
#                                                     path
# 0      /glade/campaign/cesm/development/bgcwg/project...
# 1      /glade/campaign/cesm/development/bgcwg/project...
# 2      /glade/campaign/cesm/development/bgcwg/project...
# 3      /glade/campaign/cesm/development/bgcwg/project...
# 4      /glade/campaign/cesm/development/bgcwg/project...
# ...                                                  ...
# 17981  /glade/campaign/cesm/development/bgcwg/project...
# 17982  /glade/campaign/cesm/development/bgcwg/project...
# 17983  /glade/campaign/cesm/development/bgcwg/project...
# 17984  /glade/campaign/cesm/development/bgcwg/project...
# 17985  /glade/campaign/cesm/development/bgcwg/project...
#
# [17926 rows x 13 columns]

# %% [markdown]
# There are only a few invalid assets - we can ignore these!

# %%
b.invalid_assets.INVALID_ASSET.values[0]
# Out:
# PosixPath('/glade/campaign/cesm/development/bgcwg/projects/hi-res_JRA/cases/g.e22.G1850ECO_JRA_HR.TL319_t13.003/output/ocn/proc/za.old/za_g.e22.G1850ECO_JRA_HR.TL319_t13.003.pop.h.0004-07.nc')

# %% [markdown]
# ## Save the Catalog

# %%
b.save(
    '/glade/work/mgrover/intake-esm-catalogs/hires-marbl.csv',
    path_column_name='path',
    variable_column_name='variable',
    data_format='netcdf',
    groupby_attrs=[
        'component',
        'stream',
         'case',
    ],
    aggregations=[
        {'type': 'union', 'attribute_name': 'variable'},
        {
            'type': 'join_existing',
            'attribute_name': 'time_range',
            'options': {'dim': 'time', 'coords': 'minimal', 'compat': 'override'},
        },
        {
            'type': 'join_new',
            'attribute_name': 'member_id',
            'options': {'coords': 'minimal', 'compat': 'override'},
        },
    ],
)
# Out:
# Saved catalog location: /glade/work/mgrover/intake-esm-catalogs/hires-marbl.json and /glade/work/mgrover/intake-esm-catalogs/hires-marbl.csv

# %% [markdown]
# ## Use the Catalog

# %%
import intake

# %%
col = intake.open_esm_datastore('/glade/work/mgrover/intake-esm-catalogs/hires-marbl.json')

# %%
dsets = col.search(variable='TEMP').to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.stream.case'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00<00:00]
#     </div>

# %%
dsets
# Out:
# {'ocn.pop.h.g.e22.G1850ECO_JRA_HR.TL319_t13.003': <xarray.Dataset>
#  Dimensions:                 (d2: 2, member_id: 1, nlat: 2400, nlon: 3600, time: 48, z_t: 62, z_t_150m: 15, z_w: 62, z_w_bot: 62, z_w_top: 62)
#  Coordinates:
#    * z_t                     (z_t) float32 500.0 1.5e+03 ... 5.625e+05 5.875e+05
#    * z_t_150m                (z_t_150m) float32 500.0 1.5e+03 ... 1.45e+04
#    * z_w                     (z_w) float32 0.0 1e+03 2e+03 ... 5.5e+05 5.75e+05
#    * z_w_top                 (z_w_top) float32 0.0 1e+03 ... 5.5e+05 5.75e+05
#    * z_w_bot                 (z_w_bot) float32 1e+03 2e+03 ... 5.75e+05 6e+05
#      ULONG                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      ULAT                    (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      TLONG                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      TLAT                    (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#    * time                    (time) object 0002-02-01 00:00:00 ... 0002-01-01 ...
#    * member_id               (member_id) float64 3.0
#  Dimensions without coordinates: d2, nlat, nlon
#  Data variables: (12/52)
#      dz                      (z_t) float32 dask.array<chunksize=(62,), meta=np.ndarray>
#      dzw                     (z_w) float32 dask.array<chunksize=(62,), meta=np.ndarray>
#      KMT                     (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      KMU                     (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      REGION_MASK             (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      UAREA                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      ...                      ...
#      salinity_factor         float64 ...
#      sflux_factor            float64 ...
#      nsurface_t              float64 ...
#      nsurface_u              float64 ...
#      time_bound              (time, d2) object dask.array<chunksize=(12, 2), meta=np.ndarray>
#      TEMP                    (member_id, time, z_t, nlat, nlon) float32 dask.array<chunksize=(1, 12, 62, 2400, 3600), meta=np.ndarray>
#  Attributes:
#      title:                   g.e22.G1850ECO_JRA_HR.TL319_t13.003
#      Conventions:             CF-1.0; http://www.cgd.ucar.edu/cms/eaton/netcdf...
#      revision:                $Id$
#      intake_esm_varname:      ['TEMP']
#      history:                 none
#      contents:                Diagnostic and Prognostic Variables
#      source:                  CCSM POP2, the CCSM Ocean Component
#      cell_methods:            cell_methods = time: mean ==> the variable value...
#      time_period_freq:        month_1
#      calendar:                All years have exactly  365 days.
#      model_doi_url:           https://doi.org/10.5065/D67H1H0V
#      intake_esm_dataset_key:  ocn.pop.h.g.e22.G1850ECO_JRA_HR.TL319_t13.003,
#  'ocn.pop.h.g.e22.G1850ECO_JRA_HR.TL319_t13.004': <xarray.Dataset>
#  Dimensions:                 (d2: 2, member_id: 1, nlat: 2400, nlon: 3600, time: 408, z_t: 62, z_t_150m: 15, z_w: 62, z_w_bot: 62, z_w_top: 62)
#  Coordinates:
#    * z_t                     (z_t) float32 500.0 1.5e+03 ... 5.625e+05 5.875e+05
#    * z_t_150m                (z_t_150m) float32 500.0 1.5e+03 ... 1.45e+04
#    * z_w                     (z_w) float32 0.0 1e+03 2e+03 ... 5.5e+05 5.75e+05
#    * z_w_top                 (z_w_top) float32 0.0 1e+03 ... 5.5e+05 5.75e+05
#    * z_w_bot                 (z_w_bot) float32 1e+03 2e+03 ... 5.75e+05 6e+05
#      ULONG                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      ULAT                    (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      TLONG                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      TLAT                    (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#    * time                    (time) object 0002-02-01 00:00:00 ... 0025-01-01 ...
#    * member_id               (member_id) float64 4.0
#  Dimensions without coordinates: d2, nlat, nlon
#  Data variables: (12/52)
#      dz                      (z_t) float32 dask.array<chunksize=(62,), meta=np.ndarray>
#      dzw                     (z_w) float32 dask.array<chunksize=(62,), meta=np.ndarray>
#      KMT                     (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      KMU                     (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      REGION_MASK             (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      UAREA                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#      ...                      ...
#      salinity_factor         float64 ...
#      sflux_factor            float64 ...
#      nsurface_t              float64 ...
#      nsurface_u              float64 ...
#      time_bound              (time, d2) object dask.array<chunksize=(12, 2), meta=np.ndarray>
#      TEMP                    (member_id, time, z_t, nlat, nlon) float32 dask.array<chunksize=(1, 12, 62, 2400, 3600), meta=np.ndarray>
#  Attributes:
#      title:                   g.e22.G1850ECO_JRA_HR.TL319_t13.004
#      Conventions:             CF-1.0; http://www.cgd.ucar.edu/cms/eaton/netcdf...
#      revision:                $Id$
#      intake_esm_varname:      ['TEMP']
#      history:                 none
#      contents:                Diagnostic and Prognostic Variables
#      source:                  CCSM POP2, the CCSM Ocean Component
#      cell_methods:            cell_methods = time: mean ==> the variable value...
#      time_period_freq:        month_1
#      calendar:                All years have exactly  365 days.
#      model_doi_url:           https://doi.org/10.5065/D67H1H0V
#      intake_esm_dataset_key:  ocn.pop.h.g.e22.G1850ECO_JRA_HR.TL319_t13.004}

# %%
ds = dsets['ocn.pop.h.g.e22.G1850ECO_JRA_HR.TL319_t13.004'].isel(time=0, z_t=0)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (d2: 2, member_id: 1, nlat: 2400, nlon: 3600, z_t_150m: 15, z_w: 62, z_w_bot: 62, z_w_top: 62)
# Coordinates:
#     z_t                     float32 500.0
#   * z_t_150m                (z_t_150m) float32 500.0 1.5e+03 ... 1.45e+04
#   * z_w                     (z_w) float32 0.0 1e+03 2e+03 ... 5.5e+05 5.75e+05
#   * z_w_top                 (z_w_top) float32 0.0 1e+03 ... 5.5e+05 5.75e+05
#   * z_w_bot                 (z_w_bot) float32 1e+03 2e+03 ... 5.75e+05 6e+05
#     ULONG                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#     ULAT                    (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#     TLONG                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#     TLAT                    (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#     time                    object 0002-02-01 00:00:00
#   * member_id               (member_id) float64 4.0
# Dimensions without coordinates: d2, nlat, nlon
# Data variables: (12/52)
#     dz                      float32 dask.array<chunksize=(), meta=np.ndarray>
#     dzw                     (z_w) float32 dask.array<chunksize=(62,), meta=np.ndarray>
#     KMT                     (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#     KMU                     (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#     REGION_MASK             (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#     UAREA                   (nlat, nlon) float64 dask.array<chunksize=(2400, 3600), meta=np.ndarray>
#     ...                      ...
#     salinity_factor         float64 ...
#     sflux_factor            float64 ...
#     nsurface_t              float64 ...
#     nsurface_u              float64 ...
#     time_bound              (d2) object dask.array<chunksize=(2,), meta=np.ndarray>
#     TEMP                    (member_id, nlat, nlon) float32 dask.array<chunksize=(1, 2400, 3600), meta=np.ndarray>
# Attributes:
#     title:                   g.e22.G1850ECO_JRA_HR.TL319_t13.004
#     Conventions:             CF-1.0; http://www.cgd.ucar.edu/cms/eaton/netcdf...
#     revision:                $Id$
#     intake_esm_varname:      ['TEMP']
#     history:                 none
#     contents:                Diagnostic and Prognostic Variables
#     source:                  CCSM POP2, the CCSM Ocean Component
#     cell_methods:            cell_methods = time: mean ==> the variable value...
#     time_period_freq:        month_1
#     calendar:                All years have exactly  365 days.
#     model_doi_url:           https://doi.org/10.5065/D67H1H0V
#     intake_esm_dataset_key:  ocn.pop.h.g.e22.G1850ECO_JRA_HR.TL319_t13.004
